# %% [markdown]
# **What is the difference between hardware and software? Give one example of each.**
#
# **Hardware:** The mouse is a physical peripheral you hold in your hand to move a cursor on the screen.
#
# **Software:** A Web BrowserApplications like Google Chrome or Safari are software. They consist of code that allows you to access and view websites on the internet.
